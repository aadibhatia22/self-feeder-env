# %%
import mujoco

# Load the URDF and compile it into a MuJoCo model
model = mujoco.MjModel.from_xml_path("xml_models/base-camera-stand/robot.urdf")

# Save it as a native MuJoCo XML file
mujoco.mj_saveLastXML("robot.xml", model)
# Out:
# ---------------------------------------------------------------------------
# FatalError                                Traceback (most recent call last)
# Cell In[4], line 7
#       3 # Load the URDF and compile it into a MuJoCo model
#       4 model = mujoco.MjModel.from_xml_path("xml_models/base-camera-stand/robot.urdf")
#       5
#       6 # Save it as a native MuJoCo XML file
# ----> 7 mujoco.mj_saveLastXML("/xml_models/base-camera-stand/robot.xml", model)
#
# FatalError: File not found
